# %%
from classes import Pergunta, Pessoa
import pandas as pd

pessoas = []
df = pd.read_excel("Dados_Iluminator.xlsx")
for pessoa in df.iloc[:, 0]:
    pessoas.append(Pessoa(df, pessoa))

print(pessoas)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from classes import Pergunta, Pessoa
#       2 import pandas as pd
#       4 pessoas = []
#
# ImportError: cannot import name 'Pessoa' from 'classes' (c:\Users\joaquim25018\Downloads\Ilumnator\classes.py)
